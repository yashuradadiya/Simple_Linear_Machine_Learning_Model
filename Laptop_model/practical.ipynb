# %%
# scr_type = df['ScreenResolution'].str.split(' ').apply(lambda x: ' '.join(x[:-1]))
# # Remove Resolution (Numeric value je chhe te)
# df.insert(loc = 4,column = 'ScreenType',value = scr_type) # Add Data Into main Dataframe
# df['ScreenType'] = df['ScreenType'].replace('',df['ScreenType'].mode()[0])
# # Null value ne mode thi fill karavi (Still I wannn Change)

# %%
# df['Cpu_frequency(Ghz)'] = df['Cpu'].str.split(' ').str.get(-1).str.split('').apply(lambda x: ''.join([c for c in x if c not in ['G', 'H', 'z']])).astype('float64') 
# # Cpu wadi column mathi Cpu ni Frequency ne Float value ma convert kari new column ma store kri

# %%
# df['Cpu'] = df['Cpu'].str.split().apply(lambda x: x[:-1]).str.join(' ')
# # main column mathi Frequency remove kari

# %%
# is_Intel = df['Cpu'].apply(lambda x: x.split()[1] if 'Intel' in x else 'No')
# df.insert(loc = 6,
#           column = 'Cpu_Is_Intel',
#           value = is_Intel) 
# # Jo Cpu Intel hoi to teno type and na hoi to no ne save kri ne main data frame ma insert karavi

# %%
# jo Intel Core hoi to teni Generation Store kare and na hoi to no
# Cpu_Intel_core =  df.Cpu[df['Cpu'].str.split(' ').str.slice(0,2).str.join(' ')=='Intel Core'] 
# df['Cpu_Intel_Core_Gen'] =  Cpu_Intel_core.str.split(' ').str.get(2)
# df['Cpu_Intel_Core_Gen'].fillna('No',inplace=True)
# df['Cpu_Intel_Core_Gen']

# %%
# df['Weight(kg)'] = df['Weight'].str.replace('kg','').astype('float64')
# # df = df.rename(columns={'Weight': 'Weight(kg)'})
# # Remove kg From Weight value and convert it into Float datatype

# %%
# df['Memory'] = df['Memory'].str.split(' ').apply(lambda x: ' '.join(x[1:]))
# df = df.rename(columns={'Memory':'Memory_type'})

# %%
# import pandas as pd
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_11580\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# df = pd.read_csv('laptop_data.csv')

# %%
# df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
# df["Memory"] = df["Memory"].str.replace('GB', '')
# df["Memory"] = df["Memory"].str.replace('TB', '000')
# new = df["Memory"].str.split("+", n = 1, expand = True)

# df["first"]= new[0]
# df["first"]=df["first"].str.strip()

# df["second"]= new[1]

# df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
# df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
# df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
# df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# df['first'] = df['first'].str.replace(r'\D', '',regex=True)

# df["second"].fillna("0", inplace = True)

# df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
# df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
# df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
# df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# df['second'] = df['second'].str.replace(r'\D', '',regex=True)
# # df['first']
# df["first"] = df["first"].astype(float)
# df["second"] = df["second"].astype(float)

# df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
# df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
# df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
# df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

# df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
#        'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
#        'Layer2Flash_Storage'],inplace=True)

# %%
df
# Out:
#        No. Company            TypeName  Inches  \
# 0        0   Apple           Ultrabook    13.3
# 1        1   Apple           Ultrabook    13.3
# 2        2      HP            Notebook    15.6
# 3        3   Apple           Ultrabook    15.4
# 4        4   Apple           Ultrabook    13.3
# ...    ...     ...                 ...     ...
# 1298  1298  Lenovo  2 in 1 Convertible    14.0
# 1299  1299  Lenovo  2 in 1 Convertible    13.3
# 1300  1300  Lenovo            Notebook    14.0
# 1301  1301      HP            Notebook    15.6
# 1302  1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# ...
