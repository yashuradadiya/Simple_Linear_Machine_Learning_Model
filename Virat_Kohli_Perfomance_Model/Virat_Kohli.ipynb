# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Q-1.  Read Data

# %%
df = pd.read_csv('Virat_Kohli.csv')

# %%
df
# Out:
#      Runs   BF  4s  6s      SR  Pos Dismissal  Inns     Opposition  \
# 0      12   22   1   0   54.54  2.0       lbw     1    v Sri Lanka
# 1      37   67   6   0   55.22  2.0    caught     2    v Sri Lanka
# 2      25   38   4   0   65.78  1.0   run out     1    v Sri Lanka
# 3      54   66   7   0   81.81  1.0    bowled     1    v Sri Lanka
# 4      31   46   3   1   67.39  1.0       lbw     2    v Sri Lanka
# ..    ...  ...  ..  ..     ...  ...       ...   ...            ...
# 127    45   51   2   1   88.23  3.0    caught     2  v New Zealand
# 128    65   76   2   1   85.52  3.0    caught     1  v New Zealand
# 129   122  105   8   5  116.19  3.0    caught     2      v England
# 130     8    5   2   0  160.00  3.0    caught     1      v England
# 131    55   63   8   0   87.30  3.0    caught     2      v England
#
#             Ground Start Date
# 0         Dambulla  18-Aug-08
# 1         Dambulla  20-Aug-08
# 2    Colombo (RPS)  24-Aug-08
# 3    Colombo (RPS)  27-Aug-08
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Runs        132 non-null    int64
#  1   BF          132 non-null    int64
#  2   4s          132 non-null    int64
#  3   6s          132 non-null    int64
#  4   SR          132 non-null    float64
#  5   Pos         132 non-null    float64
#  6   Dismissal   132 non-null    object
#  7   Inns        132 non-null    int64
#  8   Opposition  132 non-null    object
#  9   Ground      132 non-null    object
#  10  Start Date  132 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 11.5+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Q-2. Findout null values

# %%
df.isnull().sum()
# Out:
# Runs          0
# BF            0
# 4s            0
# 6s            0
# SR            0
# Pos           0
# Dismissal     0
# Inns          0
# Opposition    0
# Ground        0
# Start Date    0
# dtype: int64

# %% [markdown]
# There is No Null Value In This DataFrame

# %% [markdown]
# ### Q-3. The dataset contains matches played by Virat Kohli between 18 August 2008 and 22 January 2017. Find total runs scored by Virat Kohli:

# %%
df['Runs'].sum()
# Out:
# 6184

# %% [markdown]
# Virat Kohli Scored **total 6184 Runs** From 18 Auguest 2008 to 22 January 2017

# %%
plt.figure(figsize=(30,8))
plt.plot(df['Runs'],marker='o')
plt.axhline(df['Runs'].mean(),linestyle='--',color='r')

# %%
df['Runs'].mean()
# Out:
# 46.84848484848485

# %% [markdown]
# Virat Kohli's **average** runs from 18 Auguest 200 to 22 January 2017 is **46-47**.

# %% [markdown]
# ### Q-4. Find average of Virat Kohli during the same period

# %%
df['Runs'].median()
# Out:
# 32.5

# %% [markdown]
# Virat Kohli's **median** runs from 18 Auguest 200 to 22 January 2017 is **32-33**.

# %%
sns.boxplot(df['Runs'])
# Out:
# <Axes: ylabel='Runs'>

# %% [markdown]
# ### Q-5. look at the trend of runs scored by Virat Kohli in his career from 18 August 2008 to 22 January 2017:

# %%
plt.figure(figsize=(30,8))
plt.bar(df['Start Date'],df['Runs'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Q-6.Find all the batting positions played by Virat Kohli:

# %%
sorted(df['Pos'].unique().astype(int))
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# There are 1 to 7 positios played by Virat Kohli

# %% [markdown]
# ### Q-7.  Create pie chart of above analyzed data

# %%
total_value = {}
for i in range(1,8):
    total_value["Betting Position "+str(i)] = (df['Pos']==i).sum()
total_value
# Out:
# {'Betting Position 1': 3,
#  'Betting Position 2': 3,
#  'Betting Position 3': 91,
#  'Betting Position 4': 28,
#  'Betting Position 5': 3,
#  'Betting Position 6': 1,
#  'Betting Position 7': 3}

# %%
plt.figure(figsize=(6,6))
plt.pie(total_value.values(),labels=total_value.values(),colors = ["#7E8BCD", "#91CCB6", "#D892C0", "#7FD3E5", "#A086BC", "#F9A881", "#C6E0B4"])
plt.legend(loc='best', labels=total_value.keys(),bbox_to_anchor=(1,0.4))
plt.title('Count batting positions played at paticular position')
plt.show()

# %% [markdown]
# ### Q-8. look at the total runs scored by Virat Kohli in different positions:

# %%
run_count = {}
for i in range(1,8):
    run_count['Run at position '+str(i)] = (df.Runs[df['Pos']==i]).sum()
run_count
# Out:
# {'Run at position 1': 110,
#  'Run at position 2': 51,
#  'Run at position 3': 4477,
#  'Run at position 4': 1370,
#  'Run at position 5': 123,
#  'Run at position 6': 23,
#  'Run at position 7': 30}

# %%
plt.figure(figsize=(6,6))
patches,texts= plt.pie(run_count.values(),labels=run_count.values(),colors = ["#7E8BCD", "#91CCB6", "#D892C0", "#7FD3E5", "#A086BC", "#F9A881", "#C6E0B4"])
plt.legend(loc='best', labels=run_count.keys(),bbox_to_anchor=(1,0.4))
plt.title('Count Runs at paticular Betting position')
for text in texts:
    text.set_horizontalalignment('center')
plt.show()

# %% [markdown]
# ### Q-9. find out the number of centuries scored by Virat Kohli while batting in the first innings and second innings:

# %%
df['Inns'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
cen = {
    'first_inning' : (df.Inns[(df['Inns']==1) & (df['Runs']>=100)]).count(),
    'second_inning' : (df.Inns[(df['Inns']==2) & (df['Runs']>=100)]).count()
}
cen
# Out:
# {'first_inning': 8, 'second_inning': 15}

# %%
plt.bar(cen.keys(),cen.values())
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# ### Q-10. Find the kind of dismissals Virat Kohli faced most of the time:

# %%
df['Dismissal'].unique()
# Out:
# array(['lbw', 'caught', 'run out', 'bowled', 'not out', 'stumped',
#        'hit wicket'], dtype=object)

# %%
def count_dismissal(dissmiss):
    return (df.Dismissal[df['Dismissal']==dissmiss]).count()
count_dismissals = {
    'lbw' : count_dismissal('lbw'),
    'caught' : count_dismissal('caught'),
    'run out' : count_dismissal('run out'),
    'bowled' : count_dismissal('bowled'),
    'not out' : count_dismissal('not out'),
    'stumped' : count_dismissal('stumped'),
    'hit wicket' : count_dismissal('hit wicket'),
}
count_dismissals
# Out:
# {'lbw': 9,
#  'caught': 84,
#  'run out': 10,
#  'bowled': 10,
#  'not out': 17,
#  'stumped': 1,
#  'hit wicket': 1}

# %%
sns.displot(df['Dismissal'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Virat kohli mostly get **cought out**

# %% [markdown]
# ### Q-11. Find out against which team Virat Kohli scored most of his runs:

# %%
df['Opposition'].unique()
# Out:
# array(['v Sri Lanka', 'v Australia', 'v Bangladesh', 'v South Africa',
#        'v Zimbabwe', 'v New Zealand', 'v Ireland', 'v Netherlands',
#        'v West Indies', 'v Pakistan', 'v England'], dtype=object)

# %%
def count_run(oppositer):
    return (df.Runs[df['Opposition']==oppositer]).sum()
count_runs = {
    'v Sri Lanka' : count_run('v Sri Lanka'),
    'v Australia' : count_run('v Australia'),
    'v Bangladesh' : count_run('v Bangladesh'),
    'v South Africa' : count_run('v South Africa'),
    'v Zimbabwe' : count_run('v Zimbabwe'),
    'v New Zealand' : count_run('v New Zealand'),
    'v Ireland' : count_run('v Ireland'),
    'v Netherlands' : count_run('v Netherlands'),
    'v West Indies' : count_run('v West Indies'),
    'v Pakistan' : count_run('v Pakistan'),
    'v England' : count_run('v Pakistan'),
}
count_runs
# Out:
# {'v Sri Lanka': 1084,
#  'v Australia': 999,
#  'v Bangladesh': 544,
#  'v South Africa': 558,
#  'v Zimbabwe': 215,
#  'v New Zealand': 877,
#  'v Ireland': 34,
#  'v Netherlands': 12,
#  'v West Indies': 1009,
#  'v Pakistan': 22,
#  'v England': 22}

# %%
plt.figure(figsize=(15,5))
plt.bar(count_runs.keys(),count_runs.values())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# against **Sri Lanka** team Virat Kohli scored most of his runs

# %% [markdown]
# ### Q-12. Find out against which team Virat Kohli scored most of his centuries:

# %%
def count_run(oppositer):
    return (df.Opposition[(df['Opposition']==oppositer) & (df['Runs']>=100)]).count()
count_runs = {
    'v Sri Lanka' : count_run('v Sri Lanka'),
    'v Australia' : count_run('v Australia'),
    'v Bangladesh' : count_run('v Bangladesh'),
    'v South Africa' : count_run('v South Africa'),
    'v Zimbabwe' : count_run('v Zimbabwe'),
    'v New Zealand' : count_run('v New Zealand'),
    'v Ireland' : count_run('v Ireland'),
    'v Netherlands' : count_run('v Netherlands'),
    'v West Indies' : count_run('v West Indies'),
    'v Pakistan' : count_run('v Pakistan'),
    'v England' : count_run('v Pakistan'),
}
count_runs
# Out:
# {'v Sri Lanka': 4,
#  'v Australia': 5,
#  'v Bangladesh': 3,
#  'v South Africa': 1,
#  'v Zimbabwe': 1,
#  'v New Zealand': 3,
#  'v Ireland': 0,
#  'v Netherlands': 0,
#  'v West Indies': 3,
#  'v Pakistan': 0,
#  'v England': 0}

# %%
plt.figure(figsize=(15,5))
plt.bar(count_runs.keys(),count_runs.values())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# against **Australia** team Virat Kohli scored most of his centuries

# %% [markdown]
# ### Q-13. let’s analyze Virat Kohli’s strike rate.

# %%
df['SR'].describe()
# Out:
# count    132.000000
# mean      76.991212
# std       37.874491
# min        0.000000
# 25%       61.702500
# 50%       78.710000
# 75%      100.000000
# max      209.090000
# Name: SR, dtype: float64

# %%
sns.distplot(df['SR'])
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_424\35698695.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SR'])
# <Axes: xlabel='SR', ylabel='Density'>

# %% [markdown]
# ### Q-14. let’s see whether Virat Kohli plays with high strike rates in the first innings or second innings:

# %%
strik_rate = {
    'first_inning' : df.SR[df['Inns']==1],
    'second_inning' : df.SR[df['Inns']==2]
}

# %%
plt.figure(figsize=(20,8))
sns.scatterplot(strik_rate['first_inning'])
sns.scatterplot(strik_rate['second_inning'])
plt.axhline(100,linestyle='--',color='r')

# %% [markdown]
# Yes, Virat Kohli plays with high strike rates in the first innings or second innings.<br>
# But Here we can see that in 2nd inning Virat Kohli has more high strike rates

# %% [markdown]
# ### Q-15. Find the relationship between runs scored by Virat Kohli and fours played by him in each innings:

# %%
plt.figure(figsize=(15,5))
plt.scatter(df['Runs'],df['4s'])

# %% [markdown]
# Here Number of 4s linearly change with Runs

# %% [markdown]
# ### Q-16. Find out if there is some relationship with the sixes:

# %%
plt.figure(figsize=(15,5))
plt.scatter(df['Runs'],df['6s'])

# %% [markdown]
# there was no any relation between 6s and runs
